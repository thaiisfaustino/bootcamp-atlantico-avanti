# %%
from IPython.display import Markdown
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Penguin

# %%
# @title
# Pinguins
df_penguins = sns.load_dataset('penguins')
display(Markdown("## Pinguins dataset"))
display(df_penguins.head())

display(Markdown("### Exploração dos dados"))
df_penguins.info()

display(Markdown("### Estatísticas descritivas"))
display(df_penguins.describe())
# Out:
# ## Pinguins dataset
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# ### Exploração dos dados
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
# ...

# %% [markdown]
# Dicionário de dados

# %%
# @title
# Criação de um dicionário de dados

df_dict = pd.DataFrame([
    {
        "variavel": "species",
        "descricao": "Espécie do pinguim ('Adelie', 'Chinstrap', 'Gentoo')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "island",
        "descricao": "Ilha em que o pinguim foi encontrado ('Torgersen', 'Biscoe', 'Dream')",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "bill_length_mm",
        "descricao": "Comprimento do bico do pinguim em milímetros",
        "tipo": "quantitativa",
        "subtipo": "continua"
    },{
        "variavel": "bill_depth_mm",
        "descricao": "Profundidade do bico do pinguim em milímetros",
        "tipo": "quantitativa",
        "subtipo": "continua"
    },{
        "variavel": "flipper_length_mm",
        "descricao": "Comprimento da nadadeira do pinguim em milímetros",
        "tipo": "quantitativa",
        "subtipo": "continua"
    },{
        "variavel": "body_mass_g",
        "descricao": "Massa corporal do pinguim em gramas",
        "tipo": "quantitativa",
        "subtipo": "continua"
    },{
        "variavel": "sex",
        "descricao": "Sexo do pinguim ('Male', 'Female')",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    }
])

df_dict
# Out:
#             variavel                                          descricao  \
# 0            species  Espécie do pinguim ('Adelie', 'Chinstrap', 'Ge...
# 1             island  Ilha em que o pinguim foi encontrado ('Torgers...
# 2     bill_length_mm       Comprimento do bico do pinguim em milímetros
# 3      bill_depth_mm      Profundidade do bico do pinguim em milímetros
# 4  flipper_length_mm  Comprimento da nadadeira do pinguim em milímetros
# 5        body_mass_g                Massa corporal do pinguim em gramas
# 6                sex                 Sexo do pinguim ('Male', 'Female')
#
#            tipo   subtipo
# 0   qualitativa   nominal
# 1   qualitativa   nominal
# 2  quantitativa  continua
# 3  quantitativa  continua
# 4  quantitativa  continua
# 5  quantitativa  continua
# 6   qualitativa   nominal

# %% [markdown]
# ##Visualização dos dados

# %% [markdown]
# ### Dados qualitativos

# %%
# Analisando os dados de Species
print("Variáveis:", df_penguin['species'].unique())
# Out:
# Variáveis: ['Adelie' 'Chinstrap' 'Gentoo']

# %%
fig = sns.displot(data = df_penguin, x = "species")
plt.show(fig)

# %%
# Analisando os dados de Island
print("Variáveis:", df_penguin['island'].unique())
# Out:
# Variáveis: ['Torgersen' 'Biscoe' 'Dream']

# %%
fig = sns.displot(data = df_penguin, x = "island")
plt.show(fig)

# %%
# Analisando os dados de sex
print("Variáveis:", df_penguin['sex'].unique())
# Out:
# Variáveis: ['Male' 'Female' nan]

# %%
fig = sns.displot(data = df_penguin, x = "sex")
plt.show(fig)

# %% [markdown]
# ### Dados quantitativos

# %%
print("Media:", df_penguin['bill_length_mm'].mean().round(2))
print("Mediana:", df_penguin['bill_length_mm'].median())
print("Moda:", df_penguin['bill_length_mm'].mode())
print("Amplitude:", df_penguin['bill_length_mm'].max() - df_penguin['bill_length_mm'].min())
print("Variância:", df_penguin['bill_length_mm'].var().round(2))
print("Desvio Padrão:", df_penguin['bill_length_mm'].std().round(2))
# Out:
# Media: 43.92
# Mediana: 44.45
# Moda: 0    41.1
# Name: bill_length_mm, dtype: float64
# Amplitude: 27.5
# Variância: 29.81
# Desvio Padrão: 5.46

# %%
print("Media:", df_penguin['bill_depth_mm'].mean().round(2))
print("Mediana:", df_penguin['bill_depth_mm'].median())
print("Moda:", df_penguin['bill_depth_mm'].mode())
print("Amplitude:", df_penguin['bill_depth_mm'].max() - df_penguin['bill_depth_mm'].min())
print("Variância:", df_penguin['bill_depth_mm'].var().round(2))
print("Desvio Padrão:", df_penguin['bill_depth_mm'].std().round(2))
# Out:
# Media: 17.15
# Mediana: 17.3
# Moda: 0    17.0
# Name: bill_depth_mm, dtype: float64
# Amplitude: 8.4
# Variância: 3.9
# Desvio Padrão: 1.97

# %%
print("Media:", df_penguin['flipper_length_mm'].mean().round(2))
print("Mediana:", df_penguin['flipper_length_mm'].median())
print("Moda:", df_penguin['flipper_length_mm'].mode())
print("Amplitude:", df_penguin['flipper_length_mm'].max() - df_penguin['flipper_length_mm'].min())
print("Variância:", df_penguin['flipper_length_mm'].var().round(2))
print("Desvio Padrão:", df_penguin['flipper_length_mm'].std().round(2))
# Out:
# Media: 200.92
# Mediana: 197.0
# Moda: 0    190.0
# Name: flipper_length_mm, dtype: float64
# Amplitude: 59.0
# Variância: 197.73
# Desvio Padrão: 14.06

# %%
print("Media:", df_penguin['body_mass_g'].mean().round(2))
print("Mediana:", df_penguin['body_mass_g'].median())
print("Moda:", df_penguin['body_mass_g'].mode())
print("Amplitude:", df_penguin['body_mass_g'].max() - df_penguin['body_mass_g'].min())
print("Variância:", df_penguin['body_mass_g'].var().round(2))
print("Desvio Padrão:", df_penguin['body_mass_g'].std().round(2))
# Out:
# Media: 4201.75
# Mediana: 4050.0
# Moda: 0    3800.0
# Name: body_mass_g, dtype: float64
# Amplitude: 3600.0
# Variância: 643131.08
# Desvio Padrão: 801.95
